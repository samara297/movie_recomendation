# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# %%
df=pd.read_csv("/content/Movies.csv")
df.head()
# Out:
#    id                     title               genres language  user_score  \
# 0   1  The Shawshank Redemption         Drama, Crime       en         8.7
# 1   2             The Godfather         Drama, Crime       en         8.7
# 2   3     The Godfather Part II         Drama, Crime       en         8.6
# 3   4          Schindler's List  Drama, History, War       en         8.6
# 4   5              12 Angry Men                Drama       en         8.5
#
#    runtime_hour  runtime_min release_date  vote_count
# 0             2           22   1994-09-23       27070
# 1             2           55   1972-03-14       20563
# 2             3           22   1974-12-20       12403
# 3             3           15   1993-12-15       15810
# 4             1           37   1957-04-10        8611

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# genres          0
# language        0
# user_score      0
# runtime_hour    0
# runtime_min     0
# release_date    0
# vote_count      0
# dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
genre_matrix = tfidf.fit_transform(df['genres'])
cosine_sim = cosine_similarity(genre_matrix)
cosine_sim_df = pd.DataFrame(cosine_sim,index=df['title'],columns=df['title'])
cosine_sim_df
# Out:
# title                       The Shawshank Redemption  The Godfather  \
# title
# The Shawshank Redemption                    1.000000       1.000000
# The Godfather                               1.000000       1.000000
# The Godfather Part II                       1.000000       1.000000
# Schindler's List                            0.153222       0.153222
# 12 Angry Men                                0.531158       0.531158
# ...                                              ...            ...
# Alone in the Dark                           0.000000       0.000000
# Disaster Movie                              0.000000       0.000000
# House of the Dead                           0.000000       0.000000
# Dragonball Evolution                        0.000000       0.000000
# Birdemic: Shock and Terror                  0.000000       0.000000
#
# title                       The Godfather Part II  Schindler's List  \
# title
# The Shawshank Redemption                 1.000000          0.153222
# The Godfather                            1.000000          0.153222
# The Godfather Part II                    1.000000          0.153222
# Schindler's List                         0.153222          1.000000
# 12 Angry Men                             0.531158          0.288467
# ...                                           ...               ...
# Alone in the Dark                        0.000000          0.000000
# Disaster Movie                           0.000000          0.000000
# House of the Dead                        0.000000          0.000000
# Dragonball Evolution                     0.000000          0.000000
# Birdemic: Shock and Terror               0.000000          0.000000
#
# title                       12 Angry Men  Spirited Away  The Wild Robot  \
# title
# The Shawshank Redemption        0.531158       0.000000        0.000000
# The Godfather                   0.531158       0.000000        0.000000
# The Godfather Part II           0.531158       0.000000        0.000000
# Schindler's List                0.288467       0.000000        0.000000
# 12 Angry Men                    1.000000       0.000000        0.000000
# ...                                  ...            ...             ...
# Alone in the Dark               0.000000       0.359047        0.000000
# Disaster Movie                  0.000000       0.000000        0.000000
# House of the Dead               0.000000       0.000000        0.000000
# Dragonball Evolution            0.000000       0.256001        0.430881
# Birdemic: Shock and Terror      0.000000       0.000000        0.000000
#
# title                       Dilwale Dulhania Le Jayenge  The Dark Knight  \
# title
# The Shawshank Redemption                       0.248219         0.709840
# The Godfather                                  0.248219         0.709840
# The Godfather Part II                          0.248219         0.709840
# Schindler's List                               0.134806         0.108763
# 12 Angry Men                                   0.467317         0.377037
# ...                                                 ...              ...
# Alone in the Dark                              0.000000         0.254952
# Disaster Movie                                 0.518991         0.000000
# House of the Dead                              0.000000         0.533665
# Dragonball Evolution                           0.000000         0.342645
# Birdemic: Shock and Terror                     0.427535         0.240943
#
# title                       The Green Mile  ...  The Open House  \
# title                                       ...
# The Shawshank Redemption          0.732796  ...        0.000000
# The Godfather                     0.732796  ...        0.000000
# The Godfather Part II             0.732796  ...        0.000000
# Schindler's List                  0.112280  ...        0.000000
# 12 Angry Men                      0.389230  ...        0.000000
# ...                                    ...  ...             ...
# Alone in the Dark                 0.434439  ...        0.459957
# Disaster Movie                    0.000000  ...        0.000000
# House of the Dead                 0.000000  ...        0.833941
# Dragonball Evolution              0.309755  ...        0.207491
# Birdemic: Shock and Terror        0.000000  ...        0.801984
#
# title                       Lucky Luke and the Daltons  \
# title
# The Shawshank Redemption                      0.000000
# The Godfather                                 0.000000
# The Godfather Part II                         0.000000
# Schindler's List                              0.000000
# 12 Angry Men                                  0.000000
# ...                                                ...
# Alone in the Dark                             0.000000
# Disaster Movie                                0.323361
# House of the Dead                             0.000000
# Dragonball Evolution                          0.179259
# Birdemic: Shock and Terror                    0.000000
#
# title                       Hellraiser: Revelations  \
# title
# The Shawshank Redemption                   0.000000
# The Godfather                              0.000000
# The Godfather Part II                      0.000000
# Schindler's List                           0.000000
# 12 Angry Men                               0.000000
# ...                                             ...
# Alone in the Dark                          0.587718
# Disaster Movie                             0.000000
# House of the Dead                          0.652654
# Dragonball Evolution                       0.000000
# Birdemic: Shock and Terror                 0.627645
#
# title                       The Star Wars Holiday Special  Battlefield Earth  \
# title
# The Shawshank Redemption                         0.000000           0.000000
# The Godfather                                    0.000000           0.000000
# The Godfather Part II                            0.000000           0.000000
# Schindler's List                                 0.000000           0.000000
# 12 Angry Men                                     0.000000           0.000000
# ...                                                   ...                ...
# Alone in the Dark                                0.202280           0.213266
# Disaster Movie                                   0.000000           0.000000
# House of the Dead                                0.000000           0.236829
# Dragonball Evolution                             0.419703           0.825635
# Birdemic: Shock and Terror                       0.000000           0.000000
#
# title                       Alone in the Dark  Disaster Movie  \
# title
# The Shawshank Redemption             0.000000             0.0
# The Godfather                        0.000000             0.0
# The Godfather Part II                0.000000             0.0
# Schindler's List                     0.000000             0.0
# 12 Angry Men                         0.000000             0.0
# ...                                       ...             ...
# Alone in the Dark                    1.000000             0.0
# Disaster Movie                       0.000000             1.0
# House of the Dead                    0.657819             0.0
# Dragonball Evolution                 0.466721             0.0
# Birdemic: Shock and Terror           0.368878             0.0
#
# title                       House of the Dead  Dragonball Evolution  \
# title
# The Shawshank Redemption             0.000000              0.000000
# The Godfather                        0.000000              0.000000
# The Godfather Part II                0.000000              0.000000
# Schindler's List                     0.000000              0.000000
# 12 Angry Men                         0.000000              0.000000
# ...                                       ...                   ...
# Alone in the Dark                    0.657819              0.466721
# Disaster Movie                       0.000000              0.000000
# House of the Dead                    1.000000              0.368570
# Dragonball Evolution                 0.368570              1.000000
# Birdemic: Shock and Terror           0.668808              0.166405
#
# title                       Birdemic: Shock and Terror
# title
# The Shawshank Redemption                      0.000000
# The Godfather                                 0.000000
# The Godfather Part II                         0.000000
# Schindler's List                              0.000000
# 12 Angry Men                                  0.000000
# ...                                                ...
# Alone in the Dark                             0.368878
# Disaster Movie                                0.000000
# House of the Dead                             0.668808
# Dragonball Evolution                          0.166405
# Birdemic: Shock and Terror                    1.000000
#
# [9718 rows x 9718 columns]

# %%
def recommend_movies(movie_title,df,cosine_sim):
    # Create a mapping of movie titles to their index
    indices = pd.Series(df.index, index = df['title']).drop_duplicates()

    #  # Check if the movie is in the dataset
    if movie_title not in indices:
        return "Movie not found in dataset. Please try another title."

    # return index of the movie title
    idx = indices[movie_title]

    # retrieve the index with similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))

    # return  top 5 movies based on similarity scores
    sim_scores = sorted(sim_scores,key = lambda x : x[1], reverse=True)[1:6]

    recommendations = [df.iloc[i[0]]['title'] for i in sim_scores]
    return recommendations

# %%
movie_name = "The Godfather"
recommendations = recommend_movies(movie_name, df, cosine_sim)
print(f"Movies similar to '{movie_name}':\n", recommendations)
# Out:
# Movies similar to 'The Godfather':
#  ['The Godfather', 'The Godfather Part II', 'GoodFellas', 'City of God', 'Once Upon a Time in America']
